# %%
#Import Dependencies
import matplotlib.ticker as ticker
import pandas as pd
import pprint
import numpy as np
import matplotlib.pyplot as plt
import re 
import scipy as sp

# %%
#Import cvs

Rates_Population = "Wash_State_County_Demo_Data.csv"

#read cvs

Rates_Population_df = pd.read_csv(Rates_Population)

Rates_Population_df.head(20)

# Rates_Population_df.dtypes
# Out:
#          County   Land_Surface_Area  Population  Public_Charging_Station  \
# 0          Adams            1924.98       18951                        3
# 1         Asotin             636.21       21955                        1
# 2         Benton            1700.38      182053                       16
# 3         Chelan            2920.52       73664                       14
# 4        Clallam            1738.33       72024                       19
# 5          Clark             629.00      438272                       58
# 6       Columbia             868.63        4031                        7
# 7        Cowlitz            1140.12      102072                       31
# 8        Douglas            1819.26       39183                        4
# 9          Ferry            2203.16        7657                        1
# 10      Franklin            1242.17       84508                        4
# 11      Garfield             710.69        2240                        0
# ...

# %%
Rates_Population_df.columns
# Out:
# Index(['County ', 'Land_Surface_Area', 'Population', 'Public_Charging_Station',
#        'EVs_Per_County', 'Electric_ Cost_KWhr'],
#       dtype='object')

# %%
#Create a bar graph to show charging stations by county
# # Create a group based on the values in the 'maker' column
# county_group = Rates_Population_df.groupby('County ')

# # Count how many times each maker appears in our group
# count_group = county_group['County '].count()

# # count_makers
# count_chart = Rates_Population_df.plot(kind='bar')

# # Set the xlabel and ylabel using class methods
# count_chart.set_xlabel("County")
# count_chart.set_ylabel("Number of Public EV Stations")


# plt.show()



# x = [3,1,16,14,19,58,7,31,4,1,4,0,10,7,9,738,29,9,2,5,1,5,29,11,738,29,9,2,5,1,5,29,11,96,14,23,2,90,163,465,47,2,17,29,9,47]
# plt.hist(x, bins=5)

# plt.title("Public Charging Station Count by County")
# plt.xlabel("Public Charging Station")
# plt.ylabel("County")

# Rates_Population_df[['County ','Public Charging Station ']].set_index('County ').plot(kind='bar')
# ax=plt.axes()
# ax.xaxis.set_major_locator(ticker.MultipleLocator(2))
# ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
# plt.xticks(rotation = 90)
# plt.bar('County ', 'Public Charging Station ', data = sorted_charging_station)

Rates_Population_df[['County ', 'Public_Charging_Station']].set_index('County ').plot(kind='bar')
plt.ylabel("Number of Public Charging Stations")
plt.title("Charging Station by County")
plt.grid()
plt.savefig("barplot.png")
# count_data = Rates_Population_df["County "].value_counts()
# y_data = Rates_Population_df['Public_Charging_Station']
# county_ev_count = count_data.add(y_data, fill_value=0)
# county_ev_count.plot(kind='bar', facecolor="blue")
# plt.tight_layout()

# %%
#Create a scatter plot to show surface area vs charging station
# ax=plt.axes()
# ax.xaxis.set_major_locator(ticker.MultipleLocator(2))
# ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
plt.xticks(rotation = 90)
plt.scatter(Rates_Population_df['Land_Surface_Area'], Rates_Population_df["Public_Charging_Station"], c = Rates_Population_df["Public_Charging_Station"]) 
clb = plt.colorbar()
plt.xlabel("Suface Area")
plt.ylabel("Public Charging Station")
plt.title("Surface Area Vs Charging Station")
clb.set_label("Public_Charging_Station")

plt.show()
plt.savefig("scatterplot.png")

#Analysis
# There appears to be no correlation between the Surface area public charging stations

# %%
#Number of electric vehicles by county vs Electric cost

ax=plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(2))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
plt.xticks(rotation = 90)
plt.scatter(Rates_Population_df['Electric_ Cost_KWhr'], Rates_Population_df['EVs_Per_County']) 
# clb = plt.colorbar()
plt.xlabel("Electrical Cost KW/Hour")
plt.ylabel("Electrical Vehicle Count ")
plt.title("Electrical Cost vs Electrical Vehicle Count")
# clb.set_label("Public Charging Station ")
# figsize
plt.show()

# %%
#number of Electrical vehicle vs population 

plt.xticks(rotation = 90)
plt.scatter(Rates_Population_df['EVs_Per_County'], Rates_Population_df['Population']) 
plt.xlabel("Population by County")
plt.ylabel("Number of Electrical Vehicle")
plt.title("Electrical Vehicle Vs Population")
plt.show()

# %%
#number of Electrical vehicle number vs charging stations

ax=plt.gca()

plt.scatter(Rates_Population_df["Public_Charging_Station"], Rates_Population_df['EVs_Per_County']) 
# clb = plt.colorbar()


plt.xlabel("Number of Charging Stations")
plt.ylabel("Electrical Vehicle Count ")
plt.title("Electrical Vehicle vs Charging Stations")

# clb.set_label("Public Charging Station ")
# grid=True
# figsize
# plt.show()
# plt.savefig("scatter.png")
# Out:
# Text(0.5, 1.0, 'Electrical Vehicle vs Charging Stations')

# %%
#DataFrame with top FIve 

final_df = Rates_Population_df.sort_values(by=['Public_Charging_Station'], ascending=False).head(5)
final_df


# Analysis : Population is not correlated to the number of public charging stations. 
#In fact, Spokane county has a higher population but significantly less public charging stations than Stevens County.
# Out:
#       County   Land_Surface_Area  Population  Public_Charging_Station  \
# 16       King            2115.56     2008997                      738
# 31    Spokane            1763.79      476950                      163
# 26     Pierce            1669.51      812689                       96
# 30  Snohomish            2087.27      735351                       90
# 5       Clark             629.00      438272                       58
#
#     EVs_Per_County  Electric_ Cost_KWhr
# 16           26663                10.17
# 31             876                 7.26
# 26            2861                 8.92
# 30            4940                 8.44
# 5             2284                 9.18

# %%
#Check for correlation between charging stations and population
# ax=plt.axes()
# ax.xaxis.set_major_locator(ticker.MultipleLocator(2))
# ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
plt.xticks(rotation = 90)
plt.scatter(Rates_Population_df['Population'], Rates_Population_df['Public_Charging_Station']) 
# clb = plt.colorbar()
plt.xlabel("Population by County")
plt.ylabel("Pubblic Charging Station Count ")
plt.title("Population vs Public Charging Station")
# clb.set_label("Public Charging Station ")
# figsize
plt.show()

# %%
# Top Five Counties With Public Charging Stations
labels = ['King', 'Stevens', 'Spokane', 'Pierce','Snohomish']
sizes = [47.5, 30.0, 10.0, 7.0, 5.0]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral','red']
patches, texts = plt.pie(sizes, colors=colors, shadow=True, startangle=90,)
plt.legend(patches, labels, loc="best")
plt.title("Counties With Highest Public EV Charging Stations")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
#Dont forget to save as PNG !!!!!!!!
plt.savefig("pieplot.png")

# %%
pwd
# Out:
# 'C:\\Users\\marly\\OneDrive\\Desktop\\Project-1'
